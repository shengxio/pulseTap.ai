# %%
#Copyright (c) Microsoft Corporation. All rights reserved.
#Licensed under the MIT License.

# -*- coding: utf-8 -*-

import json
import os 
from pprint import pprint
import requests

# Add your Bing Search V7 subscription key and endpoint to your environment variables.
subscription_key = os.environ['BING_SEARCH_V7_SUBSCRIPTION_KEY']
endpoint = os.environ['BING_SEARCH_V7_ENDPOINT'] + "/bing/v7.0/search"

# Query term(s) to search for. 
query = "Microsoft Cognitive Services"

# Construct a request
mkt = 'en-US'
params = { 'q': query, 'mkt': mkt }
headers = { 'Ocp-Apim-Subscription-Key': subscription_key }

# Call the API
try:
    response = requests.get(endpoint, headers=headers, params=params)
    response.raise_for_status()

    print("\nHeaders:\n")
    print(response.headers)

    print("\nJSON Response:\n")
    pprint(response.json())
except Exception as ex:
    raise ex

# %% [markdown]
# ### 1.0 setup the network

# %%
import yfinance as yf
import requests
import pandas as pd
import numpy as np

from keys import *

pd.options.display.max_rows = None

# %% [markdown]
# ### 2.0 get all the public company data through yfinance by using symbol

# %%
company_df = pd.read_csv('tickers.csv')
# Out:
#               symbol
# 0                DDD
# 1                MMM
# 2               WBAI
# 3               WUBA
# 4               EGHT
# 5                AHC
# 6                AOS
# 7               ATEN
# 8                AIR
# 9                AAN
# 10               ABB
# 11               ABT
# 12              ABBV
# 13               ANF
# 14               AGD
# 15               AWP
# 16               ACP
# 17               JEQ
# 18              ASGI
# 19               AOD
# 20               ABM
# 21               AKR
# 22              ACEL
# 23               ACN
# 24              ACCO
# 25               ATV
# 26               AYI
# 27              GOLF
# 28               ADX
# 29               PEO
# 30              ADCT
# 31              AGRO
# 32              ADNT
# 33               ADT
# 34              ATGE
# 35               AAP
# 36              ADSW
# 37               WMS
# 38              ASIX
# 39               AVK
# 40               ACM
# 41              AEFC
# 42               AEB
# 43               AEG
# 44               AER
# 45              AJRD
# 46               AMG
# 47               MGR
# 48               AFL
# 49              MITT
# 50              AGCO
# 51                 A
# 52               AEM
# 53               ADC
# 54                AL
# 55               APD
# 56               ALG
# 57               AGI
# 58               ALK
# 59               AIN
# 60               ALB
# 61               ACI
# 62                AA
# 63               ALC
# 64              ALEX
# 65               ALX
# 66               ARE
# 67               AQN
# 68              AQNA
# 69              AQNB
# 70              BABA
# 71                 Y
# 72               ATI
# 73              ALLE
# 74               ALE
# 75               ADS
# 76               AFB
# 77               AWF
# 78                AB
# 79               AIO
# 80               CBH
# 81               NCV
# 82               NCZ
# 83               ACV
# 84               NFJ
# 85               NIE
# 86              ALSN
# 87               ALL
# 88              ALLY
# 89              PINE
# 90              ALTG
# 91               AYX
# 92              ATUS
# 93                MO
# 94               ACH
# 95              ALUS
# 96              AMBC
# 97              ABEV
# 98               AMC
# 99              AMCR
# 100              AEE
# 101             AMRC
# 102             AMOV
# 103              AMX
# 104              AAT
# 105              AXL
# 106              ACC
# 107              AEO
# 108              AEP
# 109              AEL
# 110              AXP
# 111              AFG
# 112             AFGB
# 113             AFGC
# 114             AFGD
# 115             AFGH
# 116              AMH
# 117              AIG
# 118              ARL
# 119              ARA
# 120              AWR
# 121              AMT
# 122              AVD
# 123              AWK
# 124             COLD
# 125              AMP
# 126              ABC
# 127             RYCE
# 128              AMN
# 129             AMRX
# 130               AP
# 131              APH
# 132              AXR
# 133             HKIB
# 134              AME
# 135             PLAN
# 136             DYFN
# 137             FINS
# 138               AU
# 139              BUD
# 140              NLY
# 141               AM
# 142               AR
# 143             ANTM
# 144              ANH
# 145              AON
# 146              AIV
# 147              APG
# 148              ARI
# 149              APO
# 150              AFT
# 151              AIF
# 152             APLE
# 153              AIT
# 154              ATR
# 155             APTV
# 156             ARMK
# 157              ABR
# 158              ARC
# 159               MT
# 160             MTCN
# 161             ARCH
# 162              ADM
# 163             AROC
# 164             ARNC
# 165             ARCO
# 166              ACA
# 167             RCUS
# 168              ARD
# 169              ASC
# 170              AFC
# 171             ACRE
# 172             ARDC
# 173             ARES
# 174              AGX
# 175             ARGD
# 176             ARGO
# 177             ANET
# 178               AI
# 179              AIC
# 180              AIW
# 181             ARLO
# 182              AHH
# 183              ARR
# 184              AFI
# 185              AWI
# 186              ARW
# 187              AJG
# 188             APAM
# 189              ASA
# 190              ABG
# 191              ASX
# 192             ASGN
# 193              AHT
# 194              ASH
# 195             ASPN
# 196              AMK
# 197              ASB
# 198               AC
# 199              AIZ
# 200             AIZP
# 201              AGO
# 202              AZN
# 203             HOME
# 204                T
# 205              TBB
# 206              TBC
# 207             ATTO
# 208              ATH
# 209             ATKR
# 210               AT
# 211             ATCO
# 212              ATO
# 213              ACB
# 214             ATHM
# 215              ALV
# 216               AN
# 217              AZO
# 218             AVLR
# 219              AVB
# 220              AGR
# 221             AVNS
# 222             AVTR
# 223             AVYA
# 224              AVY
# 225             AVNT
# 226              AVA
# 227             AXTA
# 228              AXS
# 229               AX
# 230              AXO
# 231             AZUL
# 232             AZRE
# 233              AZZ
# 234              BGS
# 235             BMRG
# 236               BW
# 237              BGH
# 238              BMI
# 239             BCSF
# 240              BKR
# 241              BBN
# 242              BLL
# 243             BANC
# 244             BBAR
# 245             BBVA
# 246              BBD
# 247             BBDO
# 248              BCH
# 249              BLX
# 250             BSBR
# 251             BSAC
# 252             BSMX
# 253              SAN
# 254              CIB
# 255              BXS
# 256              BAC
# 257              BOH
# 258              BMO
# 259              NTB
# 260              BNS
# 261              BKU
# 262              BCS
# 263             BBDC
# 264              MCI
# 265              MPV
# 266             BNED
# 267                B
# 268             GOLD
# 269              BHC
# 270              BAX
# 271              BTE
# 272              BBX
# 273              BCE
# 274              BZH
# 275              BDX
# 276             BDXB
# 277              BDC
# 278             BRBR
# 279              BHE
# 280             BHLB
# 281             BERY
# 282              BBY
# 283             BEST
# 284             BGSF
# 285              BHP
# 286              BBL
# 287              BIG
# 288               BH
# 289             BILL
# 290             BHVN
# 291              BIO
# 292             BITA
# 293               BJ
# 294              BKH
# 295              BKI
# 296              BSM
# 297               BB
# 298             BGIO
# 299              BFZ
# 300              CII
# 301              BHK
# 302              HYT
# 303              BTZ
# 304              DSU
# 305              BGR
# 306              BDJ
# 307              EGF
# 308              FRA
# 309              BFO
# 310              BGT
# 311              BOE
# 312              BME
# 313             BMEZ
# 314              BAF
# 315              BKT
# 316              BGY
# 317              BKN
# 318              BTA
# 319              BZM
# 320              MHE
# 321              BIT
# 322              MUI
# 323              MUA
# 324              BKK
# 325              BBK
# 326              BBF
# 327              BYM
# 328              BFK
# 329              BLE
# 330              BTT
# 331              MEN
# 332              MUC
# 333              MUH
# 334              MHD
# 335              MFL
# 336              MUJ
# 337              MHN
# 338              MUE
# 339              MUS
# 340              MVT
# 341              MYC
# 342              MCA
# 343              MYD
# 344              MYF
# 345              MFT
# 346              MIY
# 347              MYJ
# 348              MYN
# 349              MPA
# 350              MQT
# 351              MYI
# 352              MQY
# 353              BNY
# 354              BQH
# 355              BSE
# 356              BFY
# 357              BCX
# 358              BST
# 359             BSTZ
# 360              BSD
# 361              BUI
# 362              BHV
# 363              BLK
# 364              BGB
# 365              BGX
# 366              BSL
# 367               BE
# 368             APRN
# 369              BXG
# 370              BXC
# 371              DCF
# 372              DHF
# 373              DMB
# 374              DSM
# 375              LEO
# 376               BA
# 377              BCC
# 378             BCEI
# 379             BOOT
# 380              BAH
# 381              BWA
# 382             BORR
# 383              SAM
# 384              BXP
# 385              BSX
# 386              BOX
# 387              BYD
# 388             BPMP
# 389               BP
# 390              BPT
# 391              BRC
# 392              BHR
# 393              BDN
# 394              BWG
# 395              LND
# 396              BAK
# 397             BRFS
# 398             MNRL
# 399             BFAM
# 400             BEDU
# 401              BSA
# 402             BSIG
# 403               BV
# 404              EAT
# 405              BCO
# 406              BMY
# 407             BMY~
# 408             VTOL
# 409              BTI
# 410              BRX
# 411             BRMK
# 412               BR
# 413              BKD
# 414              BAM
# 415              BBU
# 416             BIPC
# 417              BIP
# 418               RA
# 419             BEPC
# 420              BEP
# 421              BRO
# 422              BRT
# 423               BC
# 424              BKE
# 425              BVN
# 426              BBW
# 427               BG
# 428             BURL
# 429             BWXT
# 430               BY
# 431             CABO
# 432              CBT
# 433              COG
# 434             CACI
# 435              WHD
# 436             CADE
# 437              CAE
# 438              CAI
# 439              CAL
# 440              CWT
# 441             CALX
# 442              ELY
# 443              CPE
# 444              CPT
# 445              CCJ
# 446              CPB
# 447              CWH
# 448             GOOS
# 449               CM
# 450              CNI
# 451              CNQ
# 452               CP
# 453             CANG
# 454             CNNE
# 455              CAJ
# 456              CGC
# 457              CMD
# 458              COF
# 459              CSU
# 460             BXMT
# 461             CPRI
# 462              CMO
# 463              CAH
# 464              CSL
# 465              KMX
# 466              CCL
# 467              CUK
# 468              CRS
# 469              CSV
# 470             CARR
# 471             CARS
# 472              CRI
# 473             CVNA
# 474             CSPR
# 475             CSLT
# 476             CTLT
# 477   CTT
# 478              CAT
# 479             CATO
# 480              CBZ
# 481              CBL
# 482              CBO
# 483              IGR
# 484             CBRE
# 485              CBX
# 486             PCPL
# 487              FUN
# 488              CDR
# 489               CE
# 490              CLS
# 491            CELG~
# 492              CEL
# 493             CPAC
# 494               CX
# 495              CVE
# 496              CNC
# 497              CEN
# 498              CNP
# 499              EBR
# 500             CEPU
# 501              CCS
# 502              CTL
# 503             CDAY
# 504               CF
# 505              GIB
# 506              CHX
# 507   ECOM
# 508             CHAP
# 509             CHRA
# 510              CRL
# 511             CLDT
# 512             CMCM
# 513             CHGG
# 514              CHE
# 515               CC
# 516             CHMI
# 517              CPK
# 518              CVX
# 519             CHWY
# 520              CHS
# 521              CIM
# 522               DL
# 523              CEA
# 524              CHN
# 525              CGA
# 526              LFC
# 527              CHL
# 528              COE
# 529              SNP
# 530              ZNH
# 531              CHA
# 532              CHU
# 533              CYD
# 534              CMG
# 535              CHH
# 536               CB
# 537              CHT
# 538              CHD
# 539              CCX
# 540             CCXX
# 541             CIEN
# 542               CI
# 543              XEC
# 544              CBB
# 545              CNK
# 546             CINR
# 547              CIR
# 548              CIT
# 549             CCAC
# 550              BLW
# 551                C
# 552              CFG
# 553              CIA
# 554              CIO
# 555             CVEO
# 556              CCC
# 557              CLH
# 558              CCO
# 559              EMO
# 560              CEM
# 561              CTR
# 562              CLW
# 563             CWEN
# 564              CLF
# 565             CLPR
# 566              CLX
# 567             CLDR
# 568              NET
# 569              CMS
# 570             CMSA
# 571             CMSC
# 572             CMSD
# 573              CNA
# 574              CNF
# 575             CNHI
# 576              CNO
# 577              CEO
# 578             CNXM
# 579              CNX
# 580              KOF
# 581               KO
# 582             CCEP
# 583              CDE
# 584              FOF
# 585              CNS
# 586              UTF
# 587              LDP
# 588              MIE
# 589              RQI
# 590              RNP
# 591              PSF
# 592              RFI
# 593              CFX
# 594             CFXA
# 595               CL
# 596              CCH
# 597              CXE
# 598              CIF
# 599              CXH
# 600              CMU
# 601             CLNY
# 602             CLNC
# 603              CXP
# 604              STK
# 605              CCZ
# 606              CMA
# 607              FIX
# 608              CMC
# 609              CBU
# 610              CYH
# 611             CHCT
# 612              CIG
# 613              CBD
# 614              SBS
# 615              ELP
# 616              CCU
# 617             CODI
# 618              CMP
# 619              CRK
# 620              CAG
# 621              CXO
# 622              CCM
# 623             CNMD
# 624              COP
# 625              CCR
# 626             CEIX
# 627               ED
# 628              STZ
# 629             CSTM
# 630              TCS
# 631              CLR
# 632             VLRS
# 633             CTRA
# 634              CTB
# 635              CPS
# 636              CTK
# 637              CPA
# 638              CLB
# 639              CXW
# 640             CLGX
# 641             CORR
# 642             CPLG
# 643              COR
# 644              CNR
# 645              GLW
# 646             CAAP
# 647              GYC
# 648              OFC
# 649             CTVA
# 650              CZZ
# 651             CMRE
# 652             COTY
# 653              CUZ
# 654              CVA
# 655              CPF
# 656               CR
# 657              BAP
# 658               CS
# 659              CPG
# 660             CEQP
# 661              CRH
# 662              CRT
# 663             CAPL
# 664              CCI
# 665              CCK
# 666              CRY
# 667              CTS
# 668             CUBE
# 669              CUB
# 670              CFR
# 671             CULP
# 672              CMI
# 673             CURO
# 674               CW
# 675              SRV
# 676              SZC
# 677              CWK
# 678             CUBB
# 679             CUBI
# 680              CVI
# 681              UAN
# 682              CVS
# 683             CELP
# 684              DHI
# 685              DAN
# 686              DHR
# 687              DAC
# 688               DQ
# 689              DRI
# 690              DAR
# 691              DVA
# 692              DCP
# 693             DECK
# 694               DE
# 695              DEX
# 696              DDF
# 697              DKL
# 698               DK
# 699             DELL
# 700             DLPH
# 701              DAL
# 702              DLX
# 703              DBI
# 704             DESP
# 705               DB
# 706              DVN
# 707              DHX
# 708              DHT
# 709              DEO
# 710             DSSI
# 711              DRH
# 712              DSX
# 713              DKS
# 714              DBD
# 715              DMS
# 716              DLR
# 717              DDS
# 718              DDT
# 719              DIN
# 720              DFS
# 721              DNI
# 722             DMYT
# 723              DLB
# 724               DG
# 725                D
# 726             DCUE
# 727             DRUA
# 728              DPZ
# 729              UFS
# 730              DCI
# 731             DFIN
# 732              LPG
# 733              DSL
# 734              DBL
# 735              DLY
# 736             PLOW
# 737              DEI
# 738              DOV
# 739              DVD
# 740              DOW
# 741              RDY
# 742              DRD
# 743              DRQ
# 744               DS
# 745              DTE
# 746              DTJ
# 747              DTP
# 748              DTQ
# 749              DTW
# 750              DTY
# 751              DCO
# 752              DSE
# 753              DNP
# 754              DTF
# 755              DUC
# 756              DPG
# 757              DUK
# 758             DUKB
# 759             DUKH
# 760              DRE
# 761              DNB
# 762               DD
# 763              DXC
# 764               DY
# 765             DLNG
# 766               DT
# 767               DX
# 768              ELF
# 769              EXP
# 770   ECC
# 771             ECCB
# 772             ECCX
# 773             ECCY
# 774              EIC
# 775             ESTE
# 776              DEA
# 777              EGP
# 778              EMN
# 779             KODK
# 780              ETN
# 781              ETV
# 782              ETW
# 783               EV
# 784              EOI
# 785              EOS
# 786              EFT
# 787              EFL
# 788              EFF
# 789              EHT
# 790   ETX
# 791              EOT
# 792              EVN
# 793              ETJ
# 794              EFR
# 795              EVF
# 796              EVG
# 797              EVT
# 798              ETO
# 799              ETG
# 800              ETB
# 801              EXD
# 802              ETY
# 803              EXG
# 804              ECL
# 805               EC
# 806              EPC
# 807              EIX
# 808               EW
# 809             ELAN
# 810             ELAT
# 811             ESTC
# 812              EGO
# 813              ESI
# 814             ELVT
# 815              LLY
# 816              EFC
# 817             EARN
# 818              ERJ
# 819              EME
# 820              EEX
# 821              EBS
# 822              EMR
# 823             ESRT
# 824              EIG
# 825              EDN
# 826             ENBL
# 827              ENB
# 828             ENBA
# 829              EHC
# 830             DAVA
# 831              EXK
# 832             ENIA
# 833             ENIC
# 834              ENR
# 835               ET
# 836             EPAC
# 837              ERF
# 838              ENS
# 839                E
# 840             ENLC
# 841              EBF
# 842             ENVA
# 843              NPO
# 844              ETM
# 845              EAB
# 846              EAE
# 847              EAI
# 848              ETR
# 849              ELC
# 850              ELJ
# 851              ELU
# 852              EMP
# 853              ENJ
# 854              ENO
# 855              EZT
# 856              EPD
# 857              EVC
# 858              ENV
# 859             NVST
# 860              EVA
# 861              ENZ
# 862              EOG
# 863             EPAM
# 864              EPR
# 865              EQT
# 866              EFX
# 867             EQNR
# 868              EQH
# 869             ETRN
# 870              EQC
# 871              ELS
# 872              EQR
# 873              EQS
# 874             EROS
# 875              ESE
# 876             ESNT
# 877             EPRT
# 878             WTRG
# 879             WTRU
# 880              ESS
# 881               EL
# 882              ETH
# 883             EURN
# 884              EEA
# 885               EB
# 886              EVR
# 887               RE
# 888             EVRG
# 889             EVRI
# 890               ES
# 891             EVTC
# 892              EVH
# 893             AQUA
# 894              XAN
# 895             EXPR
# 896             EXTN
# 897              EXR
# 898              XOM
# 899              FNB
# 900               FN
# 901              FDS
# 902             FICO
# 903             SFUN
# 904             FPAC
# 905             FTCH
# 906              FPI
# 907             FSLY
# 908              FBK
# 909              FFG
# 910              AGM
# 911              FRT
# 912              FSS
# 913              FMN
# 914              FHI
# 915              FDX
# 916             RACE
# 917              FOE
# 918             FCAU
# 919              FNF
# 920              FIS
# 921              FMO
# 922             FINV
# 923              FAF
# 924              FBP
# 925              FCF
# 926             TCRW
# 927             TCRZ
# 928             FSLF
# 929              FHN
# 930               FR
# 931               AG
# 932              FRC
# 933              FFA
# 934              FMY
# 935             FDEU
# 936              FIF
# 937              FSD
# 938             FTHY
# 939              FPF
# 940   FEI
# 941              FPL
# 942              FIV
# 943              FCT
# 944              FGB
# 945              FEO
# 946              FAM
# 947               FE
# 948              FIT
# 949              FPH
# 950             FVRR
# 951              FBC
# 952              DFP
# 953              PFD
# 954              PFO
# 955              FFC
# 956              FLC
# 957              FLT
# 958             FLNG
# 959              FND
# 960              FTK
# 961              FLO
# 962              FLS
# 963              FLR
# 964              FLY
# 965             FEAC
# 966              FMC
# 967              WPF
# 968              FMX
# 969               FL
# 970                F
# 971              FOR
# 972              FTS
# 973              FTV
# 974             FTAI
# 975             FVAC
# 976              FSM
# 977             FBHS
# 978              FET
# 979              FBM
# 980             FCPT
# 981             FEDU
# 982              FNV
# 983               FC
# 984              FSB
# 985              BEN
# 986               FT
# 987               FI
# 988              FCX
# 989              FMS
# 990              FDP
# 991             RESI
# 992              FRO
# 993              FSK
# 994             FSKR
# 995              FCN
# 996               FF
# 997              GCV
# 998              GAB
# 999              GGZ
# 1000             GGT
# 1001             GUT
# 1002            GLEO
# 1003             GBL
# 1004             GNT
# 1005             GME
# 1006             GCI
# 1007             GPS
# 1008             GTX
# 1009              IT
# 1010            GLOG
# 1011            GLOP
# 1012            GTES
# 1013            GATX
# 1014            GMTA
# 1015             GCP
# 1016             GNK
# 1017            GNRC
# 1018             GAM
# 1019              GD
# 1020              GE
# 1021             GIS
# 1022              GM
# 1023             GCO
# 1024             GEL
# 1025  GEN
# 1026             GNE
# 1027               G
# 1028             GPC
# 1029             GNW
# 1030             GEO
# 1031            GPRK
# 1032            GPJA
# 1033             GGB
# 1034             GTY
# 1035             GFL
# 1036            GFLU
# 1037             GIX
# 1038            GIX~
# 1039             GIK
# 1040             GIL
# 1041             GLT
# 1042            GKOS
# 1043             GSK
# 1044              CO
# 1045            GMRE
# 1046             GNL
# 1047             GLP
# 1048             GPN
# 1049             GSL
# 1050            GSLD
# 1051            GLOB
# 1052              GL
# 1053            GMED
# 1054             GMS
# 1055            GDDY
# 1056             GOL
# 1057             GFI
# 1058            GSBD
# 1059              GS
# 1060             GER
# 1061             GMZ
# 1062             GRC
# 1063             GPX
# 1064             GGG
# 1065            GRAF
# 1066             EAF
# 1067             GHM
# 1068             GHC
# 1069            GRAM
# 1070             GVA
# 1071            GPMT
# 1072             GPK
# 1073             GTN
# 1074             AJX
# 1075            AJXA
# 1076             GWB
# 1077            GDOT
# 1078             GBX
# 1079             GHL
# 1080             GHG
# 1081             GEF
# 1082             GFF
# 1083             GPI
# 1084            GRUB
# 1085             PAC
# 1086             ASR
# 1087            AVAL
# 1088            SUPV
# 1089              TV
# 1090             GSX
# 1091             GTT
# 1092             GSH
# 1093             GES
# 1094             GGM
# 1095             GPM
# 1096             GOF
# 1097            GBAB
# 1098            GWRE
# 1099             HRB
# 1100             FUL
# 1101             HAE
# 1102             HAL
# 1103             HBB
# 1104             HBI
# 1105            HNGR
# 1106            HASI
# 1107             HOG
# 1108             HMY
# 1109             HSC
# 1110             HGH
# 1111             HIG
# 1112             HVT
# 1113              HE
# 1114            HCHC
# 1115             HCA
# 1116             HCI
# 1117             HDB
# 1118              HR
# 1119             HTA
# 1120            PEAK
# 1121              HL
# 1122             HEI
# 1123             HLX
# 1124              HP
# 1125             HLF
# 1126             HRI
# 1127            HCXY
# 1128            HCXZ
# 1129            HTGC
# 1130            HRTG
# 1131             PSV
# 1132              HT
# 1133             HSY
# 1134             HTZ
# 1135             HES
# 1136            HESM
# 1137             HPE
# 1138             HXL
# 1139            HEXO
# 1140             PCF
# 1141            HGLB
# 1142            HFRO
# 1143             HPR
# 1144             HIW
# 1145             HIL
# 1146              HI
# 1147             HRC
# 1148             HTH
# 1149             HGV
# 1150             HLT
# 1151             HNI
# 1152            HMLP
# 1153             HEP
# 1154             HFC
# 1155              HD
# 1156             HMC
# 1157             HON
# 1158             HMN
# 1159             HZN
# 1160            HTFA
# 1161             HRL
# 1162             HST
# 1163             HLI
# 1164             HOV
# 1165             HHC
# 1166             HWM
# 1167             HPQ
# 1168            HSBC
# 1169             HMI
# 1170             HNP
# 1171            HUBB
# 1172            HUBS
# 1173             HBM
# 1174             HUD
# 1175             HPP
# 1176             HUM
# 1177            HCFT
# 1178             HII
# 1179             HUN
# 1180            HUYA
# 1181               H
# 1182              HY
# 1183             IAA
# 1184             IAG
# 1185             IBN
# 1186             ICL
# 1187             IDA
# 1188             IEX
# 1189             IDT
# 1190            INFO
# 1191             ITW
# 1192            IMAX
# 1193             ICD
# 1194             IHC
# 1195             IRT
# 1196             IFN
# 1197             IBA
# 1198            INFY
# 1199             ING
# 1200              IR
# 1201            NGVT
# 1202            INGR
# 1203            IIPR
# 1204            IPHI
# 1205            INSI
# 1206             NSP
# 1207            INSP
# 1208             IBP
# 1209            ITGR
# 1210             ICE
# 1211             IHG
# 1212             IFS
# 1213             IBM
# 1214             IFF
# 1215            IFFT
# 1216             IGT
# 1217              IP
# 1218            INSW
# 1219             IPV
# 1220             IPG
# 1221             IPI
# 1222             IVC
# 1223             VBF
# 1224             VCV
# 1225             VTA
# 1226            IHIT
# 1227            IHTA
# 1228             VLT
# 1229             IVR
# 1230             OIA
# 1231             VMO
# 1232             VKQ
# 1233             VPV
# 1234             IVZ
# 1235             IQI
# 1236             VVR
# 1237             VTN
# 1238             VGM
# 1239             IIM
# 1240            IRET
# 1241            NVTA
# 1242            INVH
# 1243              IO
# 1244             IQV
# 1245             IRM
# 1246             IRS
# 1247  STAR
# 1248            ITCB
# 1249            ITUB
# 1250             ITT
# 1251             IVH
# 1252             JPM
# 1253             JAX
# 1254            JILL
# 1255             SJM
# 1256             JBL
# 1257               J
# 1258             JHX
# 1259             JHG
# 1260             JOF
# 1261             JWS
# 1262            JBGS
# 1263             JEF
# 1264            JELD
# 1265            JCAP
# 1266              JT
# 1267             JKS
# 1268             JMP
# 1269             JBT
# 1270             BTO
# 1271             HEQ
# 1272             JHS
# 1273             JHI
# 1274             HPF
# 1275             HPI
# 1276             HPS
# 1277             PDT
# 1278             HTD
# 1279             HTY
# 1280             JNJ
# 1281             JCI
# 1282             JLL
# 1283            JMIA
# 1284             JIH
# 1285            JNPR
# 1286              JP
# 1287              JE
# 1288             LRN
# 1289             KAI
# 1290            KDMN
# 1291            KAMN
# 1292             KSU
# 1293             KAR
# 1294             KMF
# 1295             KYN
# 1296              KB
# 1297             KBH
# 1298             KBR
# 1299               K
# 1300            KMPR
# 1301             KMT
# 1302              KW
# 1303             KEN
# 1304             KDP
# 1305             KEY
# 1306            KEYS
# 1307             KRC
# 1308             KRP
# 1309             KMB
# 1310             KIM
# 1311             KMI
# 1312             KFS
# 1313             KGC
# 1314             KEX
# 1315              KL
# 1316             KRG
# 1317             KKR
# 1318             KIO
# 1319            KREF
# 1320             KNX
# 1321             KNL
# 1322            KNOP
# 1323              KN
# 1324             KSS
# 1325             PHG
# 1326             KTB
# 1327             KOP
# 1328             KEP
# 1329              KF
# 1330             KFY
# 1331             KOS
# 1332             KRA
# 1333              KR
# 1334             KRO
# 1335              KT
# 1336              LB
# 1337             SCX
# 1338             LHX
# 1339              LH
# 1340            LADR
# 1341            LAIX
# 1342              LW
# 1343             LCI
# 1344             LPI
# 1345             LVS
# 1346             LGI
# 1347             LAZ
# 1348             LZB
# 1349            LCII
# 1350            LEAF
# 1351             LEA
# 1352             LEE
# 1353             LGC
# 1354            LMHA
# 1355            LMHB
# 1356             LEG
# 1357             JBK
# 1358             KTH
# 1359             KTN
# 1360            LDOS
# 1361            LEJU
# 1362            LMND
# 1363              LC
# 1364             LEN
# 1365             LII
# 1366            LEVI
# 1367             LXP
# 1368             LPL
# 1369            DFNS
# 1370             USA
# 1371             ASG
# 1372            LBRT
# 1373             LSI
# 1374            LITB
# 1375             LNC
# 1376             LIN
# 1377             LNN
# 1378              LN
# 1379            LINX
# 1380             LAD
# 1381             LAC
# 1382             LYV
# 1383            LOAK
# 1384            LTHM
# 1385            RAMP
# 1386             LYG
# 1387             SCD
# 1388             LMT
# 1389               L
# 1390            LOMA
# 1391            LGVW
# 1392             LPX
# 1393             LOW
# 1394             LXU
# 1395             LTC
# 1396             LUB
# 1397              LL
# 1398            LXFR
# 1399             LDL
# 1400             LYB
# 1401             MTB
# 1402             MDC
# 1403             MHO
# 1404             MAC
# 1405             CLI
# 1406             MFD
# 1407             MGU
# 1408             MIC
# 1409             BMA
# 1410               M
# 1411             MCN
# 1412            MSGE
# 1413            MSGS
# 1414             MMP
# 1415             MGA
# 1416              MX
# 1417             MGY
# 1418            MHLA
# 1419            MHNC
# 1420            MAIN
# 1421             MMD
# 1422             MNK
# 1423            MANU
# 1424             MTW
# 1425              MN
# 1426             MAN
# 1427             MFC
# 1428             MRO
# 1429             MPC
# 1430             MMI
# 1431             MCS
# 1432             MPX
# 1433             HZO
# 1434             MKL
# 1435             VAC
# 1436             MMC
# 1437             MLM
# 1438             MAS
# 1439            DOOR
# 1440             MTZ
# 1441              MA
# 1442            MTDR
# 1443            MTRN
# 1444            MATX
# 1445             MLP
# 1446            MAXR
# 1447             MMS
# 1448             MXL
# 1449             MEC
# 1450             MBI
# 1451             MKC
# 1452             MCD
# 1453             MUX
# 1454             MCK
# 1455             MDU
# 1456             MTL
# 1457            MDLA
# 1458             MPW
# 1459             MED
# 1460             MCC
# 1461             MCV
# 1462             MCX
# 1463            MDLQ
# 1464            MDLX
# 1465            MDLY
# 1466              MD
# 1467             MDT
# 1468            MFAC
# 1469             MRK
# 1470             MCY
# 1471             MDP
# 1472             MTH
# 1473            MTOR
# 1474             MTR
# 1475             MSB
# 1476             MEI
# 1477             MET
# 1478             MCB
# 1479             MTD
# 1480             MXE
# 1481             MXF
# 1482             MFA
# 1483             MFO
# 1484             MCR
# 1485             MGF
# 1486             MIN
# 1487             MMT
# 1488             MFM
# 1489             MFV
# 1490             MTG
# 1491             MGP
# 1492             MGM
# 1493            MFGP
# 1494             MAA
# 1495            AMPY
# 1496             MLR
# 1497             HIE
# 1498             MTX
# 1499              MG
# 1500            MUFG
# 1501            MIXT
# 1502             MFG
# 1503             MBT
# 1504            MODN
# 1505             MOD
# 1506              MC
# 1507            MOGU
# 1508             MHK
# 1509             MOH
# 1510             TAP
# 1511             MNR
# 1512              MR
# 1513             MEG
# 1514             MCO
# 1515              MS
# 1516             CAF
# 1517             MSD
# 1518             EDD
# 1519             IIF
# 1520             MOS
# 1521             MSI
# 1522             MOV
# 1523            MPLX
# 1524             MRC
# 1525             MSA
# 1526             MSM
# 1527            MSCI
# 1528            MSGN
# 1529             MLI
# 1530             MWA
# 1531             MVF
# 1532             MZA
# 1533             MUR
# 1534            MUSA
# 1535             MVO
# 1536             MVC
# 1537            MVCD
# 1538             MYE
# 1539            MYOV
# 1540             NBR
# 1541              NC
# 1542             NTP
# 1543           NTEST
# 1544            NBHC
# 1545             NFG
# 1546             NGG
# 1547             NHI
# 1548             NOV
# 1549             NPK
# 1550             NNN
# 1551            NRUC
# 1552             SID
# 1553             NSA
# 1554            NTCO
# 1555             NGS
# 1556            NGVC
# 1557             NRP
# 1558             NTZ
# 1559             NWG
# 1560             NLS
# 1561            NVGS
# 1562             NNA
# 1563              NM
# 1564             NMM
# 1565             NAV
# 1566             NCR
# 1567              NP
# 1568             NNI
# 1569            NPTN
# 1570            NSCO
# 1571            NVRO
# 1572             HYB
# 1573             NFH
# 1574              GF
# 1575            NWHM
# 1576             IRL
# 1577            NMFC
# 1578            NMFX
# 1579             EDU
# 1580            NEWR
# 1581             NRZ
# 1582             SNR
# 1583            NYCB
# 1584             NYT
# 1585             NJR
# 1586             NEU
# 1587             NEM
# 1588              NR
# 1589            NEXA
# 1590            NREF
# 1591            NXRT
# 1592             NHF
# 1593             NEP
# 1594             NEE
# 1595             NEX
# 1596             NGL
# 1597            NLSN
# 1598             NKE
# 1599            NINE
# 1600             NIO
# 1601              NI
# 1602              NL
# 1603            NOAH
# 1604             NOK
# 1605            NOMD
# 1606             NMR
# 1607             OSB
# 1608             NAT
# 1609             JWN
# 1610             NSC
# 1611             NOA
# 1612             NRT
# 1613             NOC
# 1614             NWN
# 1615             NWE
# 1616            NCLH
# 1617             NVS
# 1618             NVO
# 1619            DNOW
# 1620             NRG
# 1621             NUS
# 1622             NUE
# 1623              NS
# 1624             NSS
# 1625             NTR
# 1626             NVG
# 1627             NUV
# 1628             NUW
# 1629             NEA
# 1630             NAZ
# 1631             NKX
# 1632             NCB
# 1633             NCA
# 1634             NAC
# 1635             JCE
# 1636             JCO
# 1637             JQC
# 1638             JDD
# 1639            DIAX
# 1640            JEMD
# 1641             NEV
# 1642             JFR
# 1643             JRO
# 1644             NKG
# 1645             JGH
# 1646             JHY
# 1647            JHAA
# 1648             JHB
# 1649             NXC
# 1650             NXN
# 1651             NID
# 1652             NMY
# 1653             NMT
# 1654             NUM
# 1655             NMS
# 1656             NOM
# 1657             JLS
# 1658             JMM
# 1659             NHA
# 1660             NZF
# 1661            NMCO
# 1662             NMZ
# 1663             NMI
# 1664             NJV
# 1665             NXJ
# 1666             NRK
# 1667             NYV
# 1668             NNY
# 1669             NAN
# 1670             NUO
# 1671             NPN
# 1672             NQP
# 1673             JPC
# 1674             JPS
# 1675             JPT
# 1676             JPI
# 1677             NAD
# 1678             JRI
# 1679             JRS
# 1680            BXMX
# 1681            SPXX
# 1682             NIM
# 1683             NXP
# 1684             NXQ
# 1685             NXR
# 1686             NSL
# 1687             JSD
# 1688             NBB
# 1689             JTD
# 1690             JTA
# 1691             NPV
# 1692             NIQ
# 1693             NVT
# 1694             NVR
# 1695           CTEST
# 1696             OAC
# 1697             OXY
# 1698             OII
# 1699             OCN
# 1700             OFG
# 1701             OGE
# 1702              OI
# 1703             OIS
# 1704             ODC
# 1705             ORI
# 1706             OLN
# 1707             OHI
# 1708             OMC
# 1709            ONDK
# 1710             OGS
# 1711             OLP
# 1712            OCFT
# 1713             OMF
# 1714             OKE
# 1715             ONE
# 1716            ONTO
# 1717            OOMA
# 1718             OPY
# 1719            ORCL
# 1720            ORAN
# 1721             ORC
# 1722             OEC
# 1723             ORN
# 1724              IX
# 1725             ORA
# 1726             OSK
# 1727              OR
# 1728            SFTW
# 1729            OTIS
# 1730             OUT
# 1731             OSG
# 1732             OVV
# 1733             OMI
# 1734              OC
# 1735            ORCC
# 1736             OXM
# 1737            ROYT
# 1738            PACD
# 1739             PCG
# 1740            PCGU
# 1741             PKG
# 1742              PD
# 1743            PAGS
# 1744            PANW
# 1745             PAM
# 1746             PHX
# 1747            PARR
# 1748             PAR
# 1749            PGRE
# 1750             PKE
# 1751              PK
# 1752              PH
# 1753              PE
# 1754             PSN
# 1755            PRTY
# 1756            PAYC
# 1757             PBF
# 1758            PBFX
# 1759             BTU
# 1760             PSO
# 1761             PEB
# 1762             PBA
# 1763             PEI
# 1764            PFSI
# 1765             PMT
# 1766             PAG
# 1767             PNR
# 1768             PEN
# 1769            PFGC
# 1770             PKI
# 1771             PBT
# 1772             PVL
# 1773             PRT
# 1774            PRGO
# 1775            PRSP
# 1776             PTR
# 1777             PBR
# 1778             PFE
# 1779             GHY
# 1780             ISD
# 1781            PGTI
# 1782              PM
# 1783             PSX
# 1784            PSXP
# 1785            FENG
# 1786             DNK
# 1787             PHR
# 1788             DOC
# 1789             PDM
# 1790             PCQ
# 1791             PCK
# 1792             PZC
# 1793             PCM
# 1794             PTY
# 1795             PCN
# 1796             PCI
# 1797             PDI
# 1798            NRGX
# 1799             PGP
# 1800             PHK
# 1801             PKO
# 1802             PFL
# 1803             PFN
# 1804             PMF
# 1805             PML
# 1806             PMX
# 1807             PNF
# 1808             PNI
# 1809             PYN
# 1810             RCS
# 1811            PING
# 1812             PNW
# 1813            PINS
# 1814             PHD
# 1815             PHT
# 1816             MAV
# 1817             MHI
# 1818             PXD
# 1819            PIPR
# 1820             PBI
# 1821             PIC
# 1822             PJT
# 1823             PAA
# 1824            PAGP
# 1825            PLNT
# 1826             PLT
# 1827             AGS
# 1828             PHI
# 1829            PLYM
# 1830             PNC
# 1831             PNM
# 1832             PII
# 1833             POR
# 1834             PKX
# 1835            POST
# 1836            PSTL
# 1837             PPG
# 1838             PPX
# 1839             PPL
# 1840             PYS
# 1841             PYT
# 1842             PQG
# 1843             PDS
# 1844            APTS
# 1845             PBH
# 1846             PVG
# 1847             PRI
# 1848            PRMW
# 1849             PGZ
# 1850             PRA
# 1851              PG
# 1852             PGR
# 1853             PLD
# 1854            PUMP
# 1855             PRO
# 1856            PROS
# 1857             PBB
# 1858             PBC
# 1859             PBY
# 1860              PB
# 1861            PRLB
# 1862             PFS
# 1863             PJH
# 1864             PRH
# 1865             PRS
# 1866             PRU
# 1867             PUK
# 1868             PSB
# 1869             TLK
# 1870             PEG
# 1871             PSA
# 1872             PHM
# 1873            PSTG
# 1874             PMM
# 1875             PIM
# 1876             PMO
# 1877             PPT
# 1878             NEW
# 1879             PVH
# 1880             PZN
# 1881            QTWO
# 1882             QEP
# 1883            QGEN
# 1884             QTS
# 1885            QUAD
# 1886             KWR
# 1887              NX
# 1888             PWR
# 1889              QD
# 1890             DGX
# 1891            QUOT
# 1892            QVCC
# 1893            QVCD
# 1894            CTAA
# 1895            CTBB
# 1896            CTDD
# 1897             CTV
# 1898             CTY
# 1899             CTZ
# 1900             RRD
# 1901            RMED
# 1902             RDN
# 1903             RFL
# 1904              RL
# 1905             RRC
# 1906            RNGR
# 1907            PACK
# 1908             RJF
# 1909            RYAM
# 1910             RYN
# 1911             RTX
# 1912            RMAX
# 1913              RC
# 1914             RCA
# 1915             RCB
# 1916             RCP
# 1917            RLGY
# 1918               O
# 1919             RLH
# 1920             RWT
# 1921             RBC
# 1922              RM
# 1923              RF
# 1924             RGS
# 1925             RGA
# 1926             RZA
# 1927             RZB
# 1928              RS
# 1929            RELX
# 1930             RNR
# 1931             SOL
# 1932            RENN
# 1933            RPLA
# 1934             RSG
# 1935            REZI
# 1936             RMD
# 1937             RFP
# 1938             QSR
# 1939            RPAI
# 1940             RVI
# 1941            REVG
# 1942             REV
# 1943            RVLV
# 1944             REX
# 1945            REXR
# 1946             RXN
# 1947              RH
# 1948             RNG
# 1949             RIO
# 1950             RBA
# 1951             RAD
# 1952             RFM
# 1953             RMM
# 1954             RMI
# 1955             RIV
# 1956             RSF
# 1957             OPP
# 1958             RLI
# 1959             RLJ
# 1960             RMG
# 1961             RHI
# 1962             ROK
# 1963             RCI
# 1964             ROG
# 1965             ROL
# 1966             ROP
# 1967             RST
# 1968              RY
# 1969             RCL
# 1970             RGT
# 1971             RMT
# 1972             RVT
# 1973             RES
# 1974             RPM
# 1975             RPT
# 1976             RYB
# 1977               R
# 1978             RYI
# 1979             RHP
# 1980            SPGI
# 1981             SBR
# 1982              SB
# 1983             SFE
# 1984            SAFE
# 1985            SAIL
# 1986             CRM
# 1987             SMM
# 1988             SBH
# 1989             SJT
# 1990              SD
# 1991             PER
# 1992  SAND
# 1993              SC
# 1994             SAP
# 1995             SAF
# 1996             SAK
# 1997             SAR
# 1998             SSL
# 1999             BFS
# 2000            SCPE
# 2001             SLB
# 2002            SNDR
# 2003             SWM
# 2004            SAIC
# 2005            SALT
# 2006            SBBA
# 2007            STNG
# 2008             SMG
# 2009             KTF
# 2010             KSM
# 2011             SRL
# 2012             SCU
# 2013            SCVX
# 2014              SE
# 2015              SA
# 2016             CKH
# 2017            SMHI
# 2018             SEE
# 2019            SEAS
# 2020            WTTR
# 2021             SEM
# 2022            SLQT
# 2023             SRE
# 2024            SREA
# 2025              ST
# 2026             SXT
# 2027            SQNS
# 2028             SRG
# 2029             SCI
# 2030            SERV
# 2031             NOW
# 2032             SFL
# 2033            SHAK
# 2034             SJR
# 2035            SHLX
# 2036             SHW
# 2037            FOUR
# 2038             SHG
# 2039            SHOP
# 2040            SSTK
# 2041            SBSW
# 2042             SIG
# 2043            SBOW
# 2044              SI
# 2045             SPG
# 2046             SSD
# 2047             SHI
# 2048            SITC
# 2049            SITE
# 2050             SIX
# 2051            TSLX
# 2052             SJW
# 2053             SKM
# 2054             SKX
# 2055             SKY
# 2056             SLG
# 2057            WORK
# 2058              SM
# 2059            SMAR
# 2060             SNN
# 2061            SNAP
# 2062             SNA
# 2063            IPOB
# 2064            IPOC
# 2065             SQM
# 2066            SOGO
# 2067             SOI
# 2068             SWI
# 2069             SAH
# 2070             SON
# 2071             SNE
# 2072             SOS
# 2073             SOR
# 2074             SJI
# 2075            SJIJ
# 2076            SJIU
# 2077              SO
# 2078            SOJA
# 2079            SOJB
# 2080            SOJC
# 2081            SOJD
# 2082            SOLN
# 2083            SCCO
# 2084             LUV
# 2085             SWX
# 2086             SWN
# 2087            SPAQ
# 2088             SPE
# 2089  SPB
# 2090              SR
# 2091             SPR
# 2092            SAVE
# 2093             SRC
# 2094            SPOT
# 2095            SRLP
# 2096             SII
# 2097            SPXC
# 2098            FLOW
# 2099              SQ
# 2100             JOE
# 2101            STAG
# 2102             SMP
# 2103             SXI
# 2104             SWK
# 2105             SWT
# 2106             STN
# 2107             SGU
# 2108             SRT
# 2109            STWD
# 2110             STT
# 2111            SPLP
# 2112             SCS
# 2113             SCA
# 2114             SCM
# 2115             SCL
# 2116             STE
# 2117             STL
# 2118             STC
# 2119              SF
# 2120             SFB
# 2121             STM
# 2122             EDF
# 2123             EDI
# 2124            STON
# 2125             SRI
# 2126            STOR
# 2127             GJH
# 2128             GJO
# 2129             GJS
# 2130             SYK
# 2131             MSC
# 2132             RGR
# 2133             SPH
# 2134            SMFG
# 2135             INN
# 2136             SUM
# 2137            SMLP
# 2138             SUI
# 2139             SLF
# 2140             SXC
# 2141              SU
# 2142             STG
# 2143            NOVA
# 2144             SUN
# 2145             SHO
# 2146             SPN
# 2147             SUP
# 2148            SOAC
# 2149             SUZ
# 2150             SWZ
# 2151            SWCH
# 2152             SBE
# 2153             SYF
# 2154             SNX
# 2155             SNV
# 2156             GJP
# 2157             GJR
# 2158             GJT
# 2159             SYY
# 2160             SYX
# 2161            TLRD
# 2162             TWN
# 2163             TSM
# 2164             TAK
# 2165             TAL
# 2166            TALO
# 2167             SKT
# 2168             TPR
# 2169            TRGP
# 2170             TGT
# 2171            TARO
# 2172             TTM
# 2173             TCO
# 2174            TMHC
# 2175             TRP
# 2176             TCP
# 2177             TSI
# 2178             TEL
# 2179            TISI
# 2180             FTI
# 2181            TECK
# 2182              TK
# 2183             TGP
# 2184             TNK
# 2185            TGNA
# 2186             TRC
# 2187             HQH
# 2188             THQ
# 2189             HQL
# 2190             THW
# 2191            TDOC
# 2192             TEO
# 2193             TDY
# 2194             TFX
# 2195             VIV
# 2196             TEF
# 2197             TDA
# 2198             TDE
# 2199             TDI
# 2200             TDJ
# 2201             TDS
# 2202              TU
# 2203             TDF
# 2204             EMF
# 2205             TEI
# 2206             GIM
# 2207             TPX
# 2208              TS
# 2209             TME
# 2210             THC
# 2211             TNC
# 2212             TEN
# 2213             TVC
# 2214             TVE
# 2215             TDC
# 2216             TEX
# 2217              TX
# 2218            TRNO
# 2219             TTI
# 2220            TEVA
# 2221             TPL
# 2222             TGH
# 2223             TXT
# 2224            TFII
# 2225             AES
# 2226            AZEK
# 2227              BK
# 2228              BX
# 2229             CEE
# 2230            SCHW
# 2231             COO
# 2232             GDV
# 2233             GRX
# 2234             GDL
# 2235             THG
# 2236            THGA
# 2237             TRV
# 2238             TMO
# 2239             THR
# 2240            TPRE
# 2241             TRI
# 2242             THO
# 2243             TDW
# 2244             TIF
# 2245            TLYS
# 2246             TSU
# 2247             TKR
# 2248            TMST
# 2249             TWI
# 2250             TJX
# 2251             TOL
# 2252              TR
# 2253             BLD
# 2254             TTC
# 2255              TD
# 2256            SHLL
# 2257             NDP
# 2258             TYG
# 2259            TEAF
# 2260             NTG
# 2261             TTP
# 2262             TPZ
# 2263             TOT
# 2264             TSQ
# 2265              TM
# 2266            TRTX
# 2267              TT
# 2268             TAC
# 2269             TCI
# 2270             TDG
# 2271             RIG
# 2272             TGS
# 2273             TRU
# 2274            TREC
# 2275              TG
# 2276             THS
# 2277            TREX
# 2278              TY
# 2279             TPH
# 2280            TRNE
# 2281            TNET
# 2282             TRN
# 2283             TSE
# 2284            TPVG
# 2285            TPVY
# 2286             GTS
# 2287            TRTN
# 2288             TGI
# 2289            TROX
# 2290             TBI
# 2291             TFC
# 2292             TNP
# 2293            TUFN
# 2294             TUP
# 2295             TKC
# 2296             TPB
# 2297             TRQ
# 2298             TPC
# 2299            TWLO
# 2300            TRWH
# 2301            TWTR
# 2302             TWO
# 2303             TYL
# 2304             TSN
# 2305             USB
# 2306            USPH
# 2307            SLCA
# 2308             USX
# 2309            UBER
# 2310              UI
# 2311             UBS
# 2312             UDR
# 2313             UGI
# 2314             UGP
# 2315             UMH
# 2316              UA
# 2317             UAA
# 2318             UFI
# 2319             UNF
# 2320              UN
# 2321              UL
# 2322             UNP
# 2323             UIS
# 2324             UMC
# 2325            UNFI
# 2326             UPS
# 2327             URI
# 2328             USM
# 2329             UZA
# 2330             UZB
# 2331             UZC
# 2332               X
# 2333             UNH
# 2334             UTL
# 2335            UNVR
# 2336             UVV
# 2337             UHT
# 2338             UHS
# 2339             UVE
# 2340             UTI
# 2341             UNM
# 2342            UNMA
# 2343              UE
# 2344             UBA
# 2345             UBP
# 2346            USFD
# 2347            USAC
# 2348            USNA
# 2349            USDP
# 2350             BIF
# 2351             VFC
# 2352             EGY
# 2353             MTN
# 2354             VAL
# 2355            VALE
# 2356             VLO
# 2357             VHI
# 2358             VMI
# 2359             VVV
# 2360            VAPO
# 2361             VAR
# 2362             VGR
# 2363             VEC
# 2364            VEDL
# 2365            VEEV
# 2366             VEL
# 2367            VNTR
# 2368             VTR
# 2369             VNE
# 2370             VER
# 2371            VRTV
# 2372              VZ
# 2373             VET
# 2374             VRS
# 2375            VCIF
# 2376             VRT
# 2377             VVI
# 2378            VICI
# 2379            VNCE
# 2380            VIPS
# 2381            SPCE
# 2382             VHC
# 2383             VGI
# 2384             ZTR
# 2385               V
# 2386             VSH
# 2387             VPG
# 2388            VIST
# 2389            VSTO
# 2390             VST
# 2391            VVNT
# 2392            VSLR
# 2393             VMW
# 2394             VOC
# 2395            VCRA
# 2396             VNO
# 2397            VJET
# 2398             IAE
# 2399             IHD
# 2400            VOYA
# 2401             IGA
# 2402             IGD
# 2403             IDE
# 2404             IID
# 2405             IRR
# 2406             PPR
# 2407             VMC
# 2408             WTI
# 2409             WPC
# 2410             WRB
# 2411             GRA
# 2412             GWW
# 2413             WNC
# 2414             WDR
# 2415              WD
# 2416             WMT
# 2417             DIS
# 2418             HCC
# 2419             WPG
# 2420             WRE
# 2421             WCN
# 2422              WM
# 2423             WAT
# 2424             WSO
# 2425             WTS
# 2426               W
# 2427             WBS
# 2428             WEC
# 2429             WEI
# 2430             WRI
# 2431             WMK
# 2432             WBT
# 2433             WFC
# 2434             EOD
# 2435            WELL
# 2436             WCC
# 2437             WST
# 2438             WAL
# 2439            WALA
# 2440             WEA
# 2441             TLI
# 2442             EMD
# 2443             GDO
# 2444             EHI
# 2445             HIX
# 2446             HIO
# 2447             HYI
# 2448             SBI
# 2449             IGI
# 2450             PAI
# 2451             MMU
# 2452             WMC
# 2453             DMO
# 2454             MTT
# 2455             MHF
# 2456             MNP
# 2457             GFY
# 2458             WIW
# 2459             WIA
# 2460             WES
# 2461              WU
# 2462             WAB
# 2463             WLK
# 2464            WLKP
# 2465             WBK
# 2466             WRK
# 2467             WHG
# 2468             WEX
# 2469              WY
# 2470             WPM
# 2471             WHR
# 2472             WTM
# 2473             WSR
# 2474             WLL
# 2475             WOW
# 2476             WMB
# 2477             WSM
# 2478             WGO
# 2479             WIT
# 2480             WNS
# 2481             WWW
# 2482              WF
# 2483              WK
# 2484             INT
# 2485             WWE
# 2486             WOR
# 2487             WPP
# 2488             WPX
# 2489            WYND
# 2490              WH
# 2491             XYF
# 2492            XFLT
# 2493             XHR
# 2494             XRX
# 2495             XIN
# 2496             XPO
# 2497             XYL
# 2498             AUY
# 2499            YELP
# 2500            YETI
# 2501            YEXT
# 2502             YRD
# 2503             DAO
# 2504             YPF
# 2505            YUMC
# 2506             YUM
# 2507             ZEN
# 2508             ZBH
# 2509             ZTS
# 2510             ZTO
# 2511             ZUO
# 2512            ZYME
# 2513            GOED
# 2514            XXII
# 2515             FAX
# 2516             IAF
# 2517             AEF
# 2518             FCO
# 2519             ACU
# 2520            ATNM
# 2521              AE
# 2522             ACY
# 2523            UAVS
# 2524             AGE
# 2525            AIRI
# 2526             AXU
# 2527             AAU
# 2528             APT
# 2529            AAMC
# 2530            AMBO
# 2531             DIT
# 2532             AMS
# 2533            USAS
# 2534            AMPE
# 2535            ANVS
# 2536            ARMP
# 2537            AINC
# 2538             AUG
# 2539             AWX
# 2540             ASM
# 2541             BTG
# 2542             BTN
# 2543             BCV
# 2544             BHB
# 2545             BRN
# 2546            BATL
# 2547            BIOX
# 2548            PHGE
# 2549             BGI
# 2550            BKTI
# 2551             BDR
# 2552            BRBS
# 2553             BRG
# 2554             DMF
# 2555            CMCL
# 2556             CEI
# 2557            CANF
# 2558            YCBD
# 2559             CVM
# 2560             CET
# 2561             LEU
# 2562            CHAQ
# 2563             CCF
# 2564             CQP
# 2565             LNG
# 2566             CVR
# 2567            CPHI
# 2568             CKX
# 2569             GLV
# 2570             GLQ
# 2571             GLO
# 2572            COHN
# 2573             CIX
# 2574            LODE
# 2575            CDOR
# 2576             MCF
# 2577             CMT
# 2578            CRMD
# 2579             CRF
# 2580             CLM
# 2581             CVU
# 2582             CIK
# 2583             DHY
# 2584            CRHM
# 2585             CTO
# 2586            CTEK
# 2587             DXR
# 2588             VCF
# 2589             VFL
# 2590             VMM
# 2591             DLA
# 2592             DNN
# 2593             DSS
# 2594             DPW
# 2595             DXF
# 2596             GRF
# 2597             EVM
# 2598             CEV
# 2599             EVV
# 2600             EIM
# 2601             ENX
# 2602             EVY
# 2603            ELMD
# 2604            ELLO
# 2605             ECF
# 2606            EMAN
# 2607             MSN
# 2608             EMX
# 2609            UUUU
# 2610            ENSV
# 2611             ELA
# 2612             EQX
# 2613             ESP
# 2614            EVBN
# 2615             EVI
# 2616             EPM
# 2617             FEN
# 2618             BDL
# 2619             FSI
# 2620             FTF
# 2621             FSP
# 2622             FRD
# 2623            FTSI
# 2624             GAU
# 2625             GGN
# 2626             JOB
# 2627             GMO
# 2628             GSB
# 2629            GSAT
# 2630            GORO
# 2631             GSV
# 2632            AUMN
# 2633             GSS
# 2634              GV
# 2635             GDP
# 2636             GTE
# 2637             GPL
# 2638             SIM
# 2639             AIM
# 2640             HMG
# 2641            HUSA
# 2642            IBIO
# 2643             IBO
# 2644             IMH
# 2645             IMO
# 2646             IOR
# 2647             IGC
# 2648            INDO
# 2649            INFU
# 2650             IHT
# 2651            NSPR
# 2652            ITRG
# 2653             INS
# 2654             THM
# 2655            INTT
# 2656            INUV
# 2657             VKI
# 2658             ISR
# 2659            ISDR
# 2660             ITP
# 2661             KLR
# 2662             KIQ
# 2663             LGL
# 2664            LCTX
# 2665             MAG
# 2666             MHH
# 2667            MTNB
# 2668             MMX
# 2669             IPB
# 2670             MTA
# 2671             MXC
# 2672            MLSS
# 2673             MYO
# 2674            NNVC
# 2675           ATEST
# 2676             NHC
# 2677            NAVB
# 2678            NTIP
# 2679             NBW
# 2680             NHS
# 2681             NML
# 2682             NBH
# 2683             NBO
# 2684             NRO
# 2685             GBR
# 2686             NEN
# 2687             NGD
# 2688             NXE
# 2689             NAK
# 2690             NOG
# 2691             NBY
# 2692              NG
# 2693             NTN
# 2694             NES
# 2695            OBLG
# 2696             OCX
# 2697            OGEN
# 2698             PTN
# 2699             PZG
# 2700             PRK
# 2701             PED
# 2702            PFNX
# 2703             HNW
# 2704            PLAG
# 2705             PLG
# 2706             PLM
# 2707              PW
# 2708             PLX
# 2709            RLGT
# 2710             UTG
# 2711             RHE
# 2712             RCG
# 2713             RVP
# 2714             REI
# 2715            SACC
# 2716            SACH
# 2717            SCCB
# 2718            SNMP
# 2719             SEB
# 2720            SENS
# 2721             SVT
# 2722            SMTS
# 2723             SIF
# 2724             SVM
# 2725            SILV
# 2726             XPL
# 2727             LOV
# 2728            STXS
# 2729             SSY
# 2730            SDPI
# 2731             SYN
# 2732            TKAT
# 2733             TRX
# 2734             TGB
# 2735             TGC
# 2736             GLU
# 2737             GGO
# 2738            TMBR
# 2739             TMP
# 2740             TAT
# 2741            TRXC
# 2742             TMQ
# 2743            TPHS
# 2744             TRT
# 2745            UFAB
# 2746            UAMY
# 2747             UUU
# 2748             URG
# 2749             UEC
# 2750             VGZ
# 2751            VNRX
# 2752            VOLT
# 2753             EAD
# 2754             ERC
# 2755             ERH
# 2756             WRN
# 2757             WYY
# 2758             WTT
# 2759            XTNT
# 2760            ZDGE
# 2761             ZOM

# %%
sym_ls = [row['symbol'] for i,row in company_df.iterrows()]

# %%
def getFinancials(x,label):
    try:
        return tickers.tickers[x].Financials.loc[label][0]
    except KeyError:
        return np.nan

# %%
def getInfo(x,label):
    try:
        return tickers.tickers[x].info[label]
    except KeyError:
        return np.nan

# %%
tickers = yf.Tickers(sym_ls)

# %%
import time

i=0
start = time.time()
total = len(sym_ls)
info_list = []
for s,t in tickers.tickers.items():
    i += 1
    try:
        info_list.append([t.info['sector'],t.info['marketCap'],t.info['shortName'],t.financials.loc['Total Revenue'][0]])
    except KeyError:
        info_list.append([np.nan,np.nan,np.nan,np.nan])
    print('status:',i,'/',total,'time:',time.time()-start,end='\r')
# Out:
# status: 2762 / 2762 time: 19051.3995373249055

# %%
info_df = pd.DataFrame(info_list,columns=['sector','market cap','name','total revenue'])

# %%
df = company_df.join(info_df)

# %%
#df['sector'].value_counts()

df.to_csv('public_2700.csv')

# %%
import winsound
duration = 5000  # milliseconds
freq = 440  # Hz
winsound.Beep(freq, duration)

# %% [markdown]
# ### 3.0 google search contact name and get their social media account (or the most relevant result)

# %%
from googlesearch import search

# %%
construction_df = pd.read_excel('LinkedIn_Sales_Contact_400.xlsx')
# Out:
# <ipython-input-47-9e9fecbefb16>:1: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   construction_df = pd.read_excel('LinkedIn_Sales_Contact_400.xlsx')

# %%
construction_df.head()
# Out:
#                                           profileUrl                fullName  \
# 0  https://www.linkedin.com/sales/people/ACwAAAAB...       Steve Bret Jensen
# 1  https://www.linkedin.com/sales/people/ACwAAA_1...            Tiffany Dinh
# 2  https://www.linkedin.com/sales/people/ACwAAARG...             Ali AlMalki
# 3  https://www.linkedin.com/sales/people/ACwAAALZ...  Kalpana Varsani, MCIPD
# 4  https://www.linkedin.com/sales/people/ACwAAABe...           Lavanya Desai
#
#     firstName        lastName  \
# 0  Steve Bret          Jensen
# 1     Tiffany            Dinh
# 2         Ali         AlMalki
# 3     Kalpana  Varsani, MCIPD
# 4     Lavanya           Desai
#
#                                               imgUrl  degree  \
# 0  https://media-exp3.licdn.com/dms/image/C5603AQ...       2
# 1  https://media-exp3.licdn.com/dms/image/C5603AQ...       2
# 2  https://media-exp3.licdn.com/dms/image/C4D03AQ...       2
# 3  https://media-exp3.licdn.com/dms/image/C4E03AQ...       2
# 4                                                NaN       2
#
#                                                title companyName  \
# 0                      Talent Acquisition Specialist     Arcadis
# 1                        Sr Manager, Human Resources       AECOM
# 2                     Senior Human Resources Manager       AECOM
# 3                            Human Resources Manager      Jacobs
# 4  Manager - Talent Management & Graduate Recruit...      Worley
#
#                                      companyUrl  \
# 0   https://www.linkedin.com/sales/company/5840
# 1  https://www.linkedin.com/sales/company/15656
# 2  https://www.linkedin.com/sales/company/15656
# 3   https://www.linkedin.com/sales/company/4025
# 4   https://www.linkedin.com/sales/company/6677
#
#                         regularCompanyUrl                            location  \
# 0   https://www.linkedin.com/company/5840      Taylor, Arizona, United States
# 1  https://www.linkedin.com/company/15656  Anaheim, California, United States
# 2  https://www.linkedin.com/company/15656                        Saudi Arabia
# 3   https://www.linkedin.com/company/4025     London, England, United Kingdom
# 4   https://www.linkedin.com/company/6677           Thane, Maharashtra, India
#
#    note                 dateAdded                                     vmid  \
# 0   NaN  2021-06-15T00:10:12.543Z  ACwAAAABxNQBAlT98PPnwF1ztJsCzmDYWvsAPK8
# 1   NaN  2021-06-15T00:10:23.222Z  ACwAAA_10tgBsu9dn-rB7il4G1ecL5p0Y_F6GeE
# 2   NaN  2021-06-15T00:10:23.222Z  ACwAAARGE5ABHsgnWZ6H6hOIExM8OLsCkMvFuco
# 3   NaN  2021-06-15T00:10:12.543Z  ACwAAALZzJgBoNTvtEkLoxKxaSVIN14IQfvO360
# 4   NaN  2021-06-15T00:10:12.467Z  ACwAAABerroBSgA1N1O-Xs7Gf0X84nRnzDtcayM
#
#                                   linkedInProfileUrl                    name  \
# 0  https://www.linkedin.com/in/ACwAAAABxNQBAlT98P...       Steve Bret Jensen
# 1  https://www.linkedin.com/in/ACwAAA_10tgBsu9dn-...            Tiffany Dinh
# 2  https://www.linkedin.com/in/ACwAAARGE5ABHsgnWZ...             Ali AlMalki
# 3  https://www.linkedin.com/in/ACwAAALZzJgBoNTvtE...  Kalpana Varsani, MCIPD
# 4  https://www.linkedin.com/in/ACwAAABerroBSgA1N1...           Lavanya Desai
#
#                                                query                 timestamp
# 0  https://www.linkedin.com/sales/lists/people/68...  2021-06-15T00:20:51.041Z
# 1  https://www.linkedin.com/sales/lists/people/68...  2021-06-15T00:20:51.041Z
# 2  https://www.linkedin.com/sales/lists/people/68...  2021-06-15T00:20:51.041Z
# 3  https://www.linkedin.com/sales/lists/people/68...  2021-06-15T00:20:51.041Z
# 4  https://www.linkedin.com/sales/lists/people/68...  2021-06-15T00:20:51.041Z

# %%
construction_df['twitter']=construction_df['fullName'].apply(lambda x: search(x+' Twitter',num_results=0)[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-1c2722b68f2b> in <module>
# ----> 1 construction_df['twitter']=construction_df['fullName'].apply(lambda x: search(x+' Twitter',num_results=0)[0])
#
# c:\users\sheng\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-56-1c2722b68f2b> in <lambda>(x)
# ----> 1 construction_df['twitter']=construction_df['fullName'].apply(lambda x: search(x+' Twitter',num_results=0)[0])
#
# IndexError: list index out of range

# %%
for i,row in construction_df.iterrows():
    print(row['fullName'])
# Out:
# Steve Bret Jensen
# Tiffany Dinh
# Ali AlMalki
# Kalpana Varsani, MCIPD
# Lavanya Desai
# Oliver Thomson
# David Stevens
# Valeria Pantoja RodrÃ­guez
# Phillipa Mauger
# Annette Lind FREC
# Andrea Moore
# Kate Geer
# Alex Camacho PHR  SHRM-CP
# Maciej SzczÄ™sny
# Catherine Macdonald
# Caitlan V.
# Caroline Kim
# Eveliina Tayfur
# Kim Mock
# Michael Truntzer
# Sharon Kitts
# Allen Lin
# Christopher Wettengel, MBA
# Daniel Perry
# Doris Lim (sHRBP, IHRP-CP)
# Silje Hilden Barningham  (she/her)
# Paulette Bennett
# Yahya AlZahrani
# Alicia Cao
# Anne-Karine Brodeur - CRHA
# Brandon McLean
# Venelina K.
# Katarzyna Campbell
# Ernest Ho
# Puja Singh
# Dana Viri Rosa
# Lindsay Gosse, CPHR
# Michael Mauro, CHRP
# Megan Tucker
# Tiffany Hypolite, SHRM-CP, CCM
# Marica Castillo
# Kayla Meinema
# Susie Stuart
# Sukhyanta Das (MBA, BA)
# Ghadah Alajmi
# Charu Sharma
# Danah AlRabiah
# Madison Seeker, PHR
# Brogan Petersen
# Jacqueline Cregan
# Veronica Bryant
# Payal Nagar
# Natalie Kravchuk
# Rebecca Ellison
# Andrew Williams, PHR
# Kim Rivera
# Fitzroy Ellis
# Lilian Vieira Lima
# Jemqueen "JJ"
# Robert Reda II, MS-HRM
# Grace Tan
# Christopher Ganpot
# Jessica Perry
# Ali Assoc CIPD
# Nadia Mirabella, CRHA
# Valerie Mollica
# Birce Ceren Ergin
# Renald Felicierta
# J C.
# Mandy Dewart
# Rachel Murray, PHR, SHRM-CP
# Sara Gonzalez
# Daniel Porter
# Savita Maurya
# Alicia Kerchansky
# Alejandra Suarez
# Katy Brose
# Marina Ceulemans
# Glen Tarrant
# Daniel Schneider
# Linde Wolterink
# Shreyasi Mishra
# Babitha Rao
# Anna Holck
# Shannon Bishop Craig, SPHR
# Rena M.
# Catherine Mooney
# Yasir Ilahi
# mungky kusanggraini
# AndrÃ©e-Anne Rousseau
# Ingrid ChÃ©nier
# Samantha Hogg, Assoc CIPD
# Jessica Argueta, PHR, SHRM-CP
# Dercio Maguengue
# Bram CollÃ©
# Karthikeyan PS
# Anil Singh
# Megan Ratliff
# Beatriz James
# Jamie Grasso

# %%
search('Misha Nikulin Twitter',num_results=0)[0]
# Out:
# ['https://twitter.com/mishanikulin?lang=en']

# %%
searchQuery = '@mishanikulin'
retweet_filter = '-filter:retweets'

q=searchQuery+retweet_filter
tweetsPerQry = 100
file_name = 'tweets_out.txt'
sinceID = None

# %%
tweetSearch(q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-17294e17cde9> in <module>
# ----> 1 tweetSearch(q)
#
# NameError: name 'tweetSearch' is not defined

# %%
def tweetSearch(q,fName='tweets_out.txt',sinceId = None):

    max_id = -1
    maxTweets = 1000

    tweetCount = 0
    print("Downloading max {0} tweets".format(maxTweets))
    with open(fName, 'w') as f:
        while tweetCount < maxTweets:
            tweets = []
            try:
                if (max_id <= 0):
                    if (not sinceId):
                        new_tweets = api.search(q=q, lang ="en", count=tweetsPerQry, tweet_mode='extended')

                    else:
                        new_tweets = api.search(q=q, lang ="en", count=tweetsPerQry,
                                            since_id=sinceId, tweet_mode='extended')
                else:
                    if (not sinceId):
                        new_tweets = api.search(q=q, lang ="en", count=tweetsPerQry,
                                            max_id=str(max_id - 1), tweet_mode='extended')
                    else:
                        new_tweets = api.search(q=q, lang ="en", count=tweetsPerQry,
                                            max_id=str(max_id - 1),
                                            since_id=sinceId, tweet_mode='extended')

                if not new_tweets:
                    print("No more tweets found")
                    break
                for tweet in new_tweets:
                    f.write(str(tweet.full_text.replace('\n','').encode("utf-8"))+"\n")

                tweetCount += len(new_tweets)
                print("Downloaded {0} tweets".format(tweetCount))
                max_id = new_tweets[-1].id

            except tweepy.TweepError as e:
                # Just exit if any error
                print("some error : " + str(e))
                break

    print ("Downloaded {0} tweets, Saved to {1}".format(tweetCount, fName))
    return True

# %%
import tweepy
import pandas as pd

auth = tweepy.OAuthHandler(TWITTER_API['Consumer Key'],TWITTER_API['Consumer Secret Key'])
auth.set_access_token(TWITTER_API['Access Token'],TWITTER_API['Access Token Secret'])

api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

tweet_df = tweet2df()

# %%
tweet_df
# Out:
#                               name  \
# 0                  Saatchi Gallery
# 1            University of Alberta
# 2               Alberta Government
# 3                  عادل علي بن علي
# 4                      Ajans Haber
# 5                           Canada
# 6              Sukhbir Singh Badal
# 7   Canadian Franchise Association
# 8                      Ajans Haber
# 9                  عادل علي بن علي
# 10                     Ajans Haber
# 11                       Wrekonize
# 12                   HowStuffWorks
# 13            Mohammed al Marzooqi
# 14               Devonne | Logical
# 15             Shiromani Akali Dal
# 16                     Ajans Haber
# 17               Devonne | Logical
# 18                 عادل علي بن علي
# 19             Sukhbir Singh Badal
# 20                     Ajans Haber
# 21                     しんばて呼んでもろて🦁
# 22                 عادل علي بن علي
# 23                               ف
# 24                     Ajans Haber
# 25                               ف
# 26                 عادل علي بن علي
# 27                     Ajans Haber
# 28                     Ajans Haber
# 29             Shiromani Akali Dal
# 30                 عادل علي بن علي
# 31                     Ajans Haber
# 32                   Chart Surgeon
# 33                     Ajans Haber
# 34                     Ajans Haber
# 35                     Ajans Haber
# 36                  United Nations
# 37                   HowStuffWorks
# 38                 عادل علي بن علي
# 39                     Ajans Haber
# 40                   Chart Surgeon
# 41                      أجمل خواطر
# 42                      أجمل خواطر
# 43                      أجمل خواطر
# 44             Dr. Byron L. Ernest
# 45                      أجمل خواطر
#
#                                                  text
# 0   🏖️ \n\n📷 ‘Beach’ painting by Australian artist...
# 1   Akanksha Bhatnagar pursued her passion for pol...
# 2   If you received your first #COVID19AB vaccine ...
# 3   لا تحزن إذا ارهقتك الهموم ، وضاقت بك الدنيا بم...
# 4   Rus heyeti, Türkiye ile uçuşların açılmasına i...
# 5   This National #IndigenousHistoryMonth, take a ...
# 6   Held meetings with office bearers &amp; worker...
# 7   Pillar To Post Home Inspectors is the largest ...
# 8   Özel tiyatro projeleri için destek başvuruları...
# 9   قال أحد الصالحين\nاقرأ ما شئت واحفظ ما شئت واك...
# 10  Avustralya, fare istilasından sonra bu kez de ...
# 11  Beautiful. Rest In Peace 🙏 https://t.co/YQsTnn...
# 12  These snakes are quite beautiful, but also qui...
# 13  👩🏻: يارب يكلمني يارب يكلمني \n\n🧔🏻: سلام عليكم...
# 14  RT @undisputed: .@ShannonSharpe on whether KD ...
# 15  ਅਧਿਆਪਕਾਂ ਦੀਆਂ ਮੰਗਾਂ ਨਾ ਮੰਨ ਕੇ ਕੈਪਟਨ ਸਰਕਾਰ ਉਨ੍ਹ...
# 16  Ermeni iddialarını reddetti, sorguya alındı\n\...
# 17  RT @FTFonFS1: "It’s not only the greatest game...
# 18  أكبر علامات حُسن الظن بالله \nاستمرارك بالدعاء...
# 19  ਸ਼੍ਰੋਮਣੀ ਅਕਾਲੀ ਦਲ-ਬਹੁਜਨ ਸਮਾਜ ਪਾਰਟੀ ਮਹਿਜ਼ ਇੱਕ ਗ...
# 20  İngiltere ile Avustralya ticaret anlaşmasında ...
# 21  #れんころ実績\n主催お疲れ様です！\n賞金確認できました！\nありがとうございました！\n...
# 22  لو تأملت حالك لوجدت ان الله أعطاك أشياء دون ان...
# 23                      jayson tatum usa jersey 💥💳💥💥💳
# 24  Ağaçlandırma seferberliği tüm bölgelerde devam...
# 25  im not a fan of america but wooo baby im about...
# 26  لا تحزن علي شئ فاتك\n" لَو كانَ خَيراً لبقى "💔...
# 27  Güvenlik güçlerince gerçekleştirilen "İlkbahar...
# 28  Almanya'nın Hessen eyaletinin İçişleri Bakanlı...
# 29  ਜਦੋਂ ਕੈਪਟਨ ਸਰਕਾਰ ਅਤੇ ਇਸਦੇ ਮੰਤਰੀਆਂ ਨੇ ਸੋਚ ਹੀ ਲਿ...
# 30  لو كانت الحياة (ابرة..) لكان رزقك (خيطا) يأتيك...
# 31  Terör örgütü PKK tarafından şehit edilişinin 4...
# 32  The gesture of #ChristianoRonaldo  putting the...
# 33  "Seni alçakça katleden bölücü korkakları bu to...
# 34  ‘Su için’ mesajı vererek Coca-Cola şişelerini ...
# 35  Örümcek istilası Avustralya'yı vurdu.\n\n🔹Deva...
# 36  UN Peacekeepers from Benin have left their fam...
# 37  And he was still growing at the time of his de...
# 38                    السلام عليكم ورحمة الله وبركاته
# 39  Çevre ve Şehircilik Bakanlığınca Marmara Deniz...
# 40  Lifestyle inflation kills your growth. \n\nSta...
# 41  خلك مثل غيرك متابع على וلعام\nخلاص  حولنا المح...
# 42  ألدموع أغلى وأصدق من\n    الابتسامة..\nلأن الإ...
# 43  أحقر آلبششر ..!\nمن يدّعِي حبك وهو يستخدمك \n ...
# 44  Greetings everyone! 👋 What a great day. It’s t...
# 45  آلقُلوبْ آلطيّبَة تَتآلفْ مْعَ بَعْضِهٓا سَريِعاً

# %%
def tweet2df(user=None,tweetNo = 50):
    tweet_df = pd.DataFrame(columns=['name','text'])
    
    if user is None:
        tweets = api.home_timeline(count=tweetNo)
    else:
        tweets = api.user_timeline(user,count=tweetNo)
    
    for tweet in tweets:
        new_df = pd.DataFrame([[tweet.user.name,tweet.text]], columns=['name','text'])
        tweet_df = tweet_df.append(new_df,ignore_index=True)

    return tweet_df

# %%
tweet_df['logic']=tweet_df['text'].str.contains('team')
tweet_df[tweet_df['logic']]['text'].values[0]
# Out:
# 'RT @NASAPrize: We are kicking off the final competition of the 3D-Printed Habitat Challenge. Two teams are competing head to head for guts,…'

# %%
import openai

openai.api_key = OPENAI_API_KEY
openaiWraper(sample_tweet,engine = 'davinci')
# Out:
# ' POSITIVE'

# %%
def openaiWraper(text,application = 'sentiment classifier',engine = 'ada'):
    openai.api_key = OPENAI_API_KEY
    
    if application == 'sentiment classifier':
        text_prompt = f'This is a tweet sentiment classifier \n\n\nTweet: "{text}"\nSentiment:'
        max_token = 3
    else:
        text_prompt = text
        max_token = 60
        
    response = openai.Completion.create(
      engine=engine,
      prompt=text_prompt,
      temperature=0.3,
      max_tokens=max_token,
      top_p=1.0,
      frequency_penalty=0.5,
      presence_penalty=0.0,
      stop=["###"]
    )
    
    text_return = response['choices'][0]['text']
    
    return text_return

# %%
response['choices'][0]['text']
# Out:
# 'Positive"\n\nThis is a tweet sentiment classifier \nTweet: "I\'m not a fan of the new Facebook layout. It\'s hard to find my friends\' updates."\nSentiment:"Negative"\n\nThis is a tweet sentiment classifier \nTweet: "I'

# %%
url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=IBM&apikey=demo'

r = requests.get(url)
data = r.json()

print(data.keys())
# Out:
# dict_keys(['Symbol', 'AssetType', 'Name', 'Description', 'CIK', 'Exchange', 'Currency', 'Country', 'Sector', 'Industry', 'Address', 'FullTimeEmployees', 'FiscalYearEnd', 'LatestQuarter', 'MarketCapitalization', 'EBITDA', 'PERatio', 'PEGRatio', 'BookValue', 'DividendPerShare', 'DividendYield', 'EPS', 'RevenuePerShareTTM', 'ProfitMargin', 'OperatingMarginTTM', 'ReturnOnAssetsTTM', 'ReturnOnEquityTTM', 'RevenueTTM', 'GrossProfitTTM', 'DilutedEPSTTM', 'QuarterlyEarningsGrowthYOY', 'QuarterlyRevenueGrowthYOY', 'AnalystTargetPrice', 'TrailingPE', 'ForwardPE', 'PriceToSalesRatioTTM', 'PriceToBookRatio', 'EVToRevenue', 'EVToEBITDA', 'Beta', '52WeekHigh', '52WeekLow', '50DayMovingAverage', '200DayMovingAverage', 'SharesOutstanding', 'SharesFloat', 'SharesShort', 'SharesShortPriorMonth', 'ShortRatio', 'ShortPercentOutstanding', 'ShortPercentFloat', 'PercentInsiders', 'PercentInstitutions', 'ForwardAnnualDividendRate', 'ForwardAnnualDividendYield', 'PayoutRatio', 'DividendDate', 'ExDividendDate', 'LastSplitFactor', 'LastSplitDate'])

# %%
design_df = pd.read_excel("Cycle 2 Desktop Research Input Data (2).xlsx",sheet_name='DesignFirms')
contractor_df = pd.read_excel("Cycle 2 Desktop Research Input Data (2).xlsx",sheet_name='Contractor Firms')
PM_df = pd.read_excel("Cycle 2 Desktop Research Input Data (2).xlsx",sheet_name='Program Management Firms')
# Out:
# <ipython-input-108-4576b4aef31a>:1: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   design_df = pd.read_excel("Cycle 2 Desktop Research Input Data (2).xlsx",sheet_name='DesignFirms')
# <ipython-input-108-4576b4aef31a>:2: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   contractor_df = pd.read_excel("Cycle 2 Desktop Research Input Data (2).xlsx",sheet_name='Contractor Firms')
# <ipython-input-108-4576b4aef31a>:3: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   PM_df = pd.read_excel("Cycle 2 Desktop Research Input Data (2).xlsx",sheet_name='Program Management Firms')

# %%
def getElement(x,n=0):
    if type(x)==type([]) and n<len(x):
        return x[n]

# %%
design_df['name'] = design_df['FIRM'].str.split(',').apply(getElement)
design_df['city'] = design_df['FIRM'].str.split(',').apply(lambda x: getElement(x,1))
design_df['state']= design_df['FIRM'].str.split(',').apply(lambda x: getElement(x,2))

contractor_df['name'] = contractor_df['FIRM'].str.split(',').apply(getElement)
contractor_df['city'] = contractor_df['FIRM'].str.split(',').apply(lambda x: getElement(x,1))
contractor_df['state']= contractor_df['FIRM'].str.split(',').apply(lambda x: getElement(x,2))

PM_df['name'] = PM_df['FIRM'].str.split(',').apply(getElement)
PM_df['city'] = PM_df['FIRM'].str.split(',').apply(lambda x: getElement(x,1))
PM_df['state']= PM_df['FIRM'].str.split(',').apply(lambda x: getElement(x,2))

# %%
def getSearchLink(x):
    return search(x)[0]

# %%
design_df['Website']=design_df['name'].apply(getSearchLink)
contractor_df['Website']=contractor_df['name'].apply(getSearchLink)
PM_df['Website']=PM_df['name'].apply(getSearchLink)

# %%
from searchtweets import load_credentials

load_credentials(filename="./twitter_api.yaml",
                 yaml_key="twitter_api",
                 env_overwrite=False)
# Out:
#   File "<ipython-input-42-ee053cc93206>", line 1
#     import search-tweets-python
#                  ^
# SyntaxError: invalid syntax
